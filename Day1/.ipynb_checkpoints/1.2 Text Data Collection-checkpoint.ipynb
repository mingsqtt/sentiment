# %% [markdown]
# ## Text Data Collection
#
# To do analysis in text, you need textual data! The sources of these data is varied. Some of them are for academic purposes - well labelled etc. But the truth is often you need to collect from the 'real-world'. These include collection from the Internet - RSS sites, google pages, social media etc.
#
# These form an important avenue to collect data from the Internet to do sentiment analysis. For eg. almost all news media provide RSS. Note that RSS is not UGC, and thence differences can be expected from social media or blogs. The content and how it is written are substantially different from 'short messages'. Most of the news content are also summarised by the headlines.
#
# In this notebook, we illustrate some examples of text data collection:
# - Rss feeds
# - Yelp (popular website by web scrapping)
# - Google search pages
# - Twitter (as usual!)

# %% [markdown]
# ## Rss Feeds
# We first illustrate with RSS Feeds.

# %%
# Importing packges
# Run this first before all code
from __future__ import unicode_literals
import os
import time
fpath = os.getcwd()
print (fpath)

import json
from feedparser import parse
from requests import get
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

TIMEOUT = 30
jsonlist = []
# Out:
# C:\Users\isstyc\Documents\NUS\Teaching\Sentiment Analytics\Workshops\Notebooks

# %%
import re, sys

def removeIndent(phrase):
    phrase=re.sub("\n",' ',phrase)
    phrase=re.sub("\r",' ',phrase)
    phrase=re.sub("\t",' ',phrase)
    return phrase

def removeWS(phrase):
    phrase=re.sub(' ','',phrase)
    return phrase

def removePunc(phrase):
    phrase=re.sub('&',' and ',phrase)
    phrase=re.sub(u"\"","\'", phrase)
    phrase=re.sub("\%","percent",phrase)
  #  phrase=re.sub(',','\,',phrase)
    return phrase

# %% [markdown]
# ### Examples of rss sites are listed below.
# - http://www.channelnewsasia.com/rss/latest_cna_biz_rss.xml # business
# - http://www.channelnewsasia.com/rss/latest_cna_sgbiz_rss.xml # sg biz
# - http://www.channelnewsasia.com/rss/latest_cna_world_rss.xml # world
# - http://www.channelnewsasia.com/rss/latest_cna_asiapac_rss.xml # asia pac
# <br>
#
# scmp
# - http://www.scmp.com/rss/2/feed  # HK
# - http://www.scmp.com/rss/10/feed  # business
# - http://www.scmp.com/rss/318421/feed # china feed

# %% [markdown]
# Code to retrieve RSS content is as below.

# %%
if __name__ == "__main__":
    newsurl = "http://www.channelnewsasia.com/rss/latest_cna_world_rss.xml"
    if os.path.exists("Data\\cna.json"): os.remove("Data\\cna.json") 
    ffile = open("Data\\cna.json","w")
    rss = parse(newsurl)
    i = 1
    # print (rss)
    for rss_entry in rss['entries']:  # note format can change time to time
        if i > 3 : break
        i += 1
            #     try:
        url_link = rss_entry['id']
        url_content = get(url_link, timeout=TIMEOUT)
        if url_content.ok == True:                
            page = url_content.content.decode('utf-8','ignore')
            soup = BeautifulSoup(page, 'html.parser')
            data = soup.find("div", {"class": "c-rte--article"}).find_all('p')
            content = ""
            for element in data:
                #print (element.text)
                content += element.text.lstrip().rstrip()          
            #print (content)
            url_label = removePunc(rss_entry['title'])
            url_id = rss_entry['id']
            url_summary = rss_entry['summary']                  

            jdata = {"url_id": url_id, "content": {"url_label": url_label,"text":content }}
            jsonlist.append(jdata)            
    #    except Exception as e:
      #      pass
        #    print (u"Error site for " + url_link)
    jdata = json.dump(jsonlist, ffile)
    ffile.close()

# %% [markdown]
# ## Data Collection from the Yelp sites
#
# Another source of data is user-generated data, of which we look at Yelp - a popular website for restuarants and other services reviews. It is possible to obtain via their website through their API. However there are limitations if done in this manner. Here, we use web scraping.

# %%
yelp_url = "https://www.yelp.com/biz/the-sushi-bar-singapore?osq=Restaurants"
ffile = open("Data\\yelp_1.json","w")

url_content = get(yelp_url)
page = url_content.content.decode('utf-8','ignore')

soup = BeautifulSoup(page, 'html.parser')
data = soup.find("script", type="application/ld+json").text.lstrip().rstrip()
data = removeIndent(data)

jsondata = json.loads(data)
json.dump(jsondata, ffile)

ffile.close()

# %% [markdown]
# ### Automation of web download
# Automating download of information from websites using Selenium.

# %%
ffile = open("Data\\yelp_2.json","w")
def getBS(data):
    soup = BeautifulSoup(data, "html.parser")
    data = soup.find("script", type="application/ld+json").text.lstrip().rstrip()
    data = removeIndent(data)
    jsondata = json.loads(data)
    return jsondata

drive=webdriver.Chrome(fpath + "\\jar\\chromedriver.exe")
drive.set_page_load_timeout(10)
yelp_url = "https://www.yelp.com/biz/the-sushi-bar-singapore?start="
i=0
drive.get(yelp_url+str(i))
time.sleep(10)
data = drive.page_source
data0 = getBS(data)  # in dict format
print ("first clicked :" + str(i) + " downloaded")
reviews = {i : data0}

NbReviews = data0['aggregateRating']['reviewCount']
print ("Total no of reviews: " +str(NbReviews))

while i< NbReviews-20:  # code can be improved to look for next button in Selenium
    i=i+20
    drive.get(yelp_url+str(i))
    print ("no of reviews :" + str(i) + " downloaded")
    time.sleep(10)
    data = drive.page_source
    data = getBS(data) 
    #data = pd.DataFrame.to_json(getBS(data))  # in json format
    reviews[i]= data 

#jsondata = json.loads(data0)
json.dump(reviews, ffile)
ffile.close()
# Out:
# first clicked :0 downloaded
# Total no of reviews: 41
# no of reviews :20 downloaded
# no of reviews :40 downloaded

# %% [markdown]
# ## Data collection from Google Search
# It is also possible to extract search snippets from google search. From then, it is a simple task to use Selenium above to extract the contents returned from the search. An example below is done for search term 'Coffee'.
#
# To do run the code below, you need to obtain an API key and also create a custom search ID from the site
# https://developers.google.com/custom-search/v1/overview?csw=1

# %%
APIKEY = 'place your API Key'

# https://developers.google.com/custom-search/v1/overview?csw=1

# %%
CSE_ID = 'place your CSE ID - custom search engine id'

# https://developers.google.com/custom-search/v1/overview?csw=1
# Also enable the "Search the entire web"

# %% [markdown]
# ![image.png](images/image.png)

# %%
# It looks something like this.........

# %% [markdown]
# ![image.png](images/image2.png)

# %%
#!pip install google-api-python-client

# %%
from googleapiclient.discovery import build
my_api_key = APIKEY
my_cse_id = CSE_ID

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res

# %%
result = google_search("Coffee", my_api_key, my_cse_id)
from pprint import pprint
pprint(result)
# Out:
# {'context': {'title': 'Coffee'},
#  'items': [{'cacheId': 'U6oJMnF-eeUJ',
#             'displayLink': 'en.wikipedia.org',
#             'formattedUrl': 'https://en.wikipedia.org/wiki/Coffee',
#             'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/<b>Coffee</b>',
#             'htmlSnippet': '<b>Coffee</b> is a brewed drink prepared from '
#                            'roasted <b>coffee</b> beans, the seeds of <br>\n'
#                            'berries from certain Coffea species. The genus '
#                            'Coffea is native to tropical Africa <br>\n'
#                            'and&nbsp;...',
#             'htmlTitle': '<b>Coffee</b> - Wikipedia',
#             'kind': 'customsearch#result',
#             'link': 'https://en.wikipedia.org/wiki/Coffee',
#             'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/A_small_cup_of_coffee.JPG/1200px-A_small_cup_of_coffee.JPG'}],
#                         'cse_thumbnail': [{'height': '194',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRgInT8Wk4JHvpHKTtvvFwDDYzBmKWeDVXlQfPneITnyqwdWGo3GF539nI',
#                                            'width': '259'}],
#                         'hrecipe': [{'fn': 'Coffee'}],
#                         'metatags': [{'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/A_small_cup_of_coffee.JPG/1200px-A_small_cup_of_coffee.JPG',
#                                       'referrer': 'origin'}]},
#             'snippet': 'Coffee is a brewed drink prepared from roasted coffee '
#                        'beans, the seeds of \n'
#                        'berries from certain Coffea species. The genus Coffea '
#                        'is native to tropical Africa \n'
#                        'and\xa0...',
#             'title': 'Coffee - Wikipedia'},
#            {'cacheId': 'FB_36c_qnUAJ',
#             'displayLink': 'www.medicalnewstoday.com',
#             'formattedUrl': 'https://www.medicalnewstoday.com/articles/270202.php',
#             'htmlFormattedUrl': 'https://www.medicalnewstoday.com/articles/270202.php',
#             'htmlSnippet': 'Jul 10, 2019 <b>...</b> Drinking <b>coffee</b> can '
#                            'do much more than provide an energy boost. Some '
#                            'scientific <br>\n'
#                            'studies have suggested that <b>coffee</b> can also '
#                            'reduce the risk of&nbsp;...',
#             'htmlTitle': '<b>Coffee</b>: Benefits, nutrition, and risks',
#             'kind': 'customsearch#result',
#             'link': 'https://www.medicalnewstoday.com/articles/270202.php',
#             'pagemap': {'cse_image': [{'src': 'https://cdn-prod.medicalnewstoday.com/content/images/hero/270/270202/270202_1100.jpg'}],
#                         'cse_thumbnail': [{'height': '194',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTF9HjHYnwAVRaJa_OzHEMB_TXzFoflTios-L-J0-asEV6bhiKvo07QrI4Y',
#                                            'width': '259'}],
#                         'metatags': [{'fb:admins': '1658973110',
#                                       'fb:app_id': '147184211975697',
#                                       'msvalidate.01': '65DAC77377665AE872AC660E37807BC6',
#                                       'og:description': 'Drinking coffee can '
#                                                         'do much more than '
#                                                         'provide an energy '
#                                                         'boost. Some '
#                                                         'scientific studies '
#                                                         'have suggested that '
#                                                         'coffee can also '
#                                                         'reduce the risk of '
#                                                         'several health '
#                                                         'issues. Learn more '
#                                                         'about the possible '
#                                                         'benefits of coffee, '
#                                                         'as well as some of '
#                                                         'the risks, here.',
#                                       'og:image': 'https://cdn-prod.medicalnewstoday.com/content/images/hero/270/270202/270202_1100.jpg',
#                                       'og:site_name': 'Medical News Today',
#                                       'og:title': 'Coffee: Benefits, '
#                                                   'nutrition, and risks',
#                                       'og:type': 'article',
#                                       'og:url': 'https://www.medicalnewstoday.com/articles/270202.php',
#                                       'p:domain_verify': 'ca332f19ebf583ba72eff99cc210a982',
#                                       'rating': 'general',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:creator': '@mnt',
#                                       'twitter:description': 'Drinking coffee '
#                                                              'can do much more '
#                                                              'than provide an '
#                                                              'energy boost. '
#                                                              'Some scientific '
#                                                              'studies have '
#                                                              'suggested that '
#                                                              'coffee can also '
#                                                              'reduce the risk '
#                                                              'of several '
#                                                              'health issues. '
#                                                              'Learn more about '
#                                                              'the possible '
#                                                              'benefits of '
#                                                              'coffee, as well '
#                                                              'as some of the '
#                                                              'risks, here.',
#                                       'twitter:domain': 'medicalnewstoday.com',
#                                       'twitter:image:src': 'https://cdn-prod.medicalnewstoday.com/content/images/hero/270/270202/270202_1100.jpg',
#                                       'twitter:site': '@mnt',
#                                       'twitter:title': 'Coffee: Benefits, '
#                                                        'nutrition, and risks',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1.0, '
#                                                   'minimum-scale=1.0, '
#                                                   'maximum-scale=1.0, '
#                                                   'user-scalable=0'}]},
#             'snippet': 'Jul 10, 2019 ... Drinking coffee can do much more than '
#                        'provide an energy boost. Some scientific \n'
#                        'studies have suggested that coffee can also reduce the '
#                        'risk of\xa0...',
#             'title': 'Coffee: Benefits, nutrition, and risks'},
#            {'cacheId': 'wfQ5Et9Ni-kJ',
#             'displayLink': 'www.amazon.com',
#             'formattedUrl': 'https://www.amazon.com/coffee/s?k=coffee',
#             'htmlFormattedUrl': 'https://www.amazon.com/<b>coffee</b>/s?k=<b>coffee</b>',
#             'htmlSnippet': 'Amazon.com: <b>coffee</b>. ... McCafe Premium '
#                            'Medium Roast Ground <b>Coffee</b> (24 oz <br>\n'
#                            'Tin) ... AmazonFresh Colombia Ground '
#                            '<b>Coffee</b>, Medium Roast, 32 Ounce.',
#             'htmlTitle': 'coffee - Amazon.com',
#             'kind': 'customsearch#result',
#             'link': 'https://www.amazon.com/coffee/s?k=coffee',
#             'snippet': 'Amazon.com: coffee. ... McCafe Premium Medium Roast '
#                        'Ground Coffee (24 oz \n'
#                        'Tin) ... AmazonFresh Colombia Ground Coffee, Medium '
#                        'Roast, 32 Ounce.',
#             'title': 'coffee - Amazon.com'},
#            {'cacheId': 'eukMDyc_TlwJ',
#             'displayLink': 'www.ncausa.org',
#             'formattedUrl': 'www.ncausa.org/about-coffee/what-is-coffee',
#             'htmlFormattedUrl': 'www.ncausa.org/about-<b>coffee</b>/what-is-<b>coffee</b>',
#             'htmlSnippet': '<b>Coffee</b> trees are pruned short to conserve '
#                            'their energy and aid in harvesting, but <br>\n'
#                            'can grow to more than 30 feet (9 meters) high. '
#                            'Each tree is covered with green,&nbsp;...',
#             'htmlTitle': 'What is <b>Coffee</b>?',
#             'kind': 'customsearch#result',
#             'link': 'http://www.ncausa.org/about-coffee/what-is-coffee',
#             'pagemap': {'cse_image': [{'src': 'http://www.ncausa.org/portals/56/Images/PageImages/NCA_Web_Med_coffee-cherry-green.png?ver=2018-02-14-153854-360'}],
#                         'cse_thumbnail': [{'height': '150',
#                                            'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcSmu5alKlUmHAZKcTkELkHXOOb3eE1twBHcmkKrezeLGKmiRQ4uPXsxNjY',
#                                            'width': '337'}],
#                         'listitem': [{'item': 'National Coffee Association',
#                                       'name': 'National Coffee Association',
#                                       'position': '1'},
#                                      {'item': 'About Coffee',
#                                       'name': 'About Coffee',
#                                       'position': '2'},
#                                      {'item': 'What is Coffee?',
#                                       'name': 'What is Coffee?',
#                                       'position': '3'}],
#                         'metatags': [{'rating': 'GENERAL',
#                                       'resource-type': 'DOCUMENT',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}]},
#             'snippet': 'Coffee trees are pruned short to conserve their energy '
#                        'and aid in harvesting, but \n'
#                        'can grow to more than 30 feet (9 meters) high. Each '
#                        'tree is covered with green,\xa0...',
#             'title': 'What is Coffee?'},
#            {'cacheId': '1vGXgo_FlHkJ',
#             'displayLink': 'www.starbucks.com',
#             'formattedUrl': 'https://www.starbucks.com/',
#             'htmlFormattedUrl': 'https://www.starbucks.com/',
#             'htmlSnippet': 'Starbucks uses the highest quality arabica '
#                            '<b>coffee</b> as the base for its espresso <br>\n'
#                            'drinks. Learn about our unique <b>coffees</b> and '
#                            'espresso drinks today.',
#             'htmlTitle': 'Starbucks – The Best <b>Coffee</b> and Espresso '
#                          'Drinks',
#             'kind': 'customsearch#result',
#             'link': 'https://www.starbucks.com/',
#             'pagemap': {'cse_image': [{'src': 'https://www.starbucks.com/static/images/global/logo.png'}],
#                         'cse_thumbnail': [{'height': '62',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQRAY5PTPbmxzfWAqc1VMqhvSqntY3WkJA5L7kKvXxAk03SQ0D7W3JiTw',
#                                            'width': '62'}],
#                         'metatags': [{'apple-itunes-app': 'app-id=331177714 , '
#                                                           'app-argument=starbucks://',
#                                       'fb:app_id': '338375791266',
#                                       'msvalidate.01': '1D2A423C9E7C5DAD0E53A99337302AE1',
#                                       'og:description': 'Starbucks uses the '
#                                                         'highest quality '
#                                                         'arabica coffee as the '
#                                                         'base for its espresso '
#                                                         'drinks. Learn about '
#                                                         'our unique coffees '
#                                                         'and espresso drinks '
#                                                         'today.',
#                                       'og:image': 'https://www.starbucks.com/static/images/global/logo.png',
#                                       'og:site_name': 'Starbucks Coffee '
#                                                       'Company',
#                                       'og:title': 'Starbucks – The Best Coffee '
#                                                   'and Espresso Drinks',
#                                       'og:type': 'company',
#                                       'og:url': 'https://www.starbucks.com/',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1'}]},
#             'snippet': 'Starbucks uses the highest quality arabica coffee as '
#                        'the base for its espresso \n'
#                        'drinks. Learn about our unique coffees and espresso '
#                        'drinks today.',
#             'title': 'Starbucks – The Best Coffee and Espresso Drinks'},
#            {'cacheId': 'u8fDpqqQvRgJ',
#             'displayLink': 'www.healthline.com',
#             'formattedUrl': 'https://www.healthline.com/.../top-13-evidence-based-health-benefits-of- '
#                             'coffee',
#             'htmlFormattedUrl': 'https://www.healthline.com/.../top-13-evidence-based-health-benefits-of- '
#                                 '<b>coffee</b>',
#             'htmlSnippet': 'Sep 20, 2018 <b>...</b> <b>Coffee</b> is the '
#                            'biggest source of antioxidants in the diet. It has '
#                            'many health benefits<br>\n'
#                            ', such as improved brain function and a lower risk '
#                            'of serious&nbsp;...',
#             'htmlTitle': '13 Health Benefits of <b>Coffee</b>, Based on '
#                          'Science',
#             'kind': 'customsearch#result',
#             'link': 'https://www.healthline.com/nutrition/top-13-evidence-based-health-benefits-of-coffee',
#             'pagemap': {'cse_image': [{'src': 'https://www.healthline.com/hlcmsresource/images/AN_images/evidence-based-health-benefits-coffee-1200x628-facebook.jpg'}],
#                         'cse_thumbnail': [{'height': '162',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcTSBOMmJsyzXyLgYvjyKpBU21JgBUQYY5sLDH0wqbQj6Lvtoq4YiUyegjV2',
#                                            'width': '311'}],
#                         'metatags': [{'fb:app_id': '1529595680591919',
#                                       'imuid': '2791758',
#                                       'k1': 'othernutrition',
#                                       'k2': 'nutrition',
#                                       'og:description': 'Coffee is the biggest '
#                                                         'source of '
#                                                         'antioxidants in the '
#                                                         'diet. It has many '
#                                                         'health benefits, such '
#                                                         'as improved brain '
#                                                         'function and a lower '
#                                                         'risk of serious '
#                                                         'diseases.',
#                                       'og:image': 'https://www.healthline.com/hlcmsresource/images/AN_images/evidence-based-health-benefits-coffee-1200x628-facebook.jpg',
#                                       'og:site_name': 'Healthline',
#                                       'og:title': '13 Health Benefits of '
#                                                   'Coffee, Based on Science',
#                                       'og:type': 'article',
#                                       'og:url': 'https://www.healthline.com/nutrition/top-13-evidence-based-health-benefits-of-coffee',
#                                       'sailthru.image.thumb': 'https://www.healthline.com/hlcmsresource/images/AN_images/evidence-based-health-benefits-coffee-732x549-thumbnail.jpg',
#                                       'sailthru.tags': 'othernutrition,nutrition',
#                                       'twitter:card': 'summary_large_image',
#                                       'twitter:creator': '@healthline',
#                                       'twitter:description': 'Coffee is the '
#                                                              'biggest source '
#                                                              'of antioxidants '
#                                                              'in the diet. It '
#                                                              'has many health '
#                                                              'benefits, such '
#                                                              'as improved '
#                                                              'brain function '
#                                                              'and a lower risk '
#                                                              'of serious '
#                                                              'diseases.',
#                                       'twitter:image': 'https://www.healthline.com/hlcmsresource/images/AN_images/evidence-based-health-benefits-coffee-732x549-thumbnail.jpg',
#                                       'twitter:site': '@healthline',
#                                       'twitter:title': '13 Health Benefits of '
#                                                        'Coffee, Based on '
#                                                        'Science',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1, '
#                                                   'user-scalable=no'}]},
#             'snippet': 'Sep 20, 2018 ... Coffee is the biggest source of '
#                        'antioxidants in the diet. It has many health benefits\n'
#                        ', such as improved brain function and a lower risk of '
#                        'serious\xa0...',
#             'title': '13 Health Benefits of Coffee, Based on Science'},
#            {'cacheId': 'WpQxSYo2c6AJ',
#             'displayLink': 'www.coffeebean.com',
#             'formattedUrl': 'https://www.coffeebean.com/',
#             'htmlFormattedUrl': 'https://www.<b>coffee</b>bean.com/',
#             'htmlSnippet': 'The <b>Coffee</b> Bean®. Rewards. Join The '
#                            '<b>Coffee</b> Bean® Rewards for free <br>\n'
#                            'beverages, special perks and Social Hour - our '
#                            'exclusive program for rewards <br>\n'
#                            'and offers.',
#             'htmlTitle': 'Home | The <b>Coffee</b> Bean &amp; Tea Leaf',
#             'kind': 'customsearch#result',
#             'link': 'https://www.coffeebean.com/',
#             'pagemap': {'cse_image': [{'src': 'https://cbtl-images.s3.us-west-1.amazonaws.com/Production/Drupal/s3fs-public/menu_icons/19FAL_Amazon_2500x2500_FriendsKCup_MED_Front.jpg'}],
#                         'cse_thumbnail': [{'height': '225',
#                                            'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRZSF5zZXDYUArGDaB4aZaA1-vbUT8GqCgsZxJYiT56Iku98L9_tFzYick',
#                                            'width': '225'}],
#                         'metatags': [{'handheldfriendly': 'true',
#                                       'mobileoptimized': 'width',
#                                       'title': 'Home | The Coffee Bean & Tea '
#                                                'Leaf',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1.0'}]},
#             'snippet': 'The Coffee Bean®. Rewards. Join The Coffee Bean® '
#                        'Rewards for free \n'
#                        'beverages, special perks and Social Hour - our '
#                        'exclusive program for rewards \n'
#                        'and offers.',
#             'title': 'Home | The Coffee Bean & Tea Leaf'},
#            {'cacheId': '7U9oPM9TV1sJ',
#             'displayLink': 'www.intelligentsiacoffee.com',
#             'formattedUrl': 'https://www.intelligentsiacoffee.com/',
#             'htmlFormattedUrl': 'https://www.intelligentsia<b>coffee</b>.com/',
#             'htmlSnippet': 'Freshly roasted and proudly poured, we&#39;re '
#                            'working every day to bring you the <br>\n'
#                            'finest Direct Trade and In Season <b>coffee</b> '
#                            'available.',
#             'htmlTitle': 'Fresh Roasted <b>Coffee</b> | Intelligentsia | '
#                          'Illuminating <b>Coffee</b>',
#             'kind': 'customsearch#result',
#             'link': 'https://www.intelligentsiacoffee.com/',
#             'pagemap': {'cse_image': [{'src': 'https://www.intelligentsiacoffee.com/media/wysiwyg/home/holiday_2018/Web-Banner-2.jpg'}],
#                         'cse_thumbnail': [{'height': '153',
#                                            'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQA8_hMGZBzg2FHViSYFgxl0mEeLK9h-Ow3ItSrZIQIpZE2Q3oT4bE0peA',
#                                            'width': '330'}],
#                         'metatags': [{'p:domain_verify': 'bb4910b2de405cc292c0776c536c6757',
#                                       'viewport': 'width=device-width, '
#                                                   'initial-scale=1, '
#                                                   'maximum-scale=1.0, '
#                                                   'user-scalable=no'}]},
#             'snippet': "Freshly roasted and proudly poured, we're working "
#                        'every day to bring you the \n'
#                        'finest Direct Trade and In Season coffee available.',
#             'title': 'Fresh Roasted Coffee | Intelligentsia | Illuminating '
#                      'Coffee'},
#            {'cacheId': 'BCjzno6zP6wJ',
#             'displayLink': 'www.peets.com',
#             'formattedUrl': 'https://www.peets.com/',
#             'htmlFormattedUrl': 'https://www.peets.com/',
#             'htmlSnippet': 'Since 1966, Peet&#39;s <b>Coffee</b> has offered '
#                            'superior <b>coffees</b> and teas by sourcing the '
#                            '<br>\n'
#                            'best quality <b>coffee</b> beans and tea leaves in '
#                            'the world and adhering to strict&nbsp;...',
#             'htmlTitle': 'Peet&#39;s <b>Coffee</b>: The Original Craft '
#                          '<b>Coffee</b>',
#             'kind': 'customsearch#result',
#             'link': 'https://www.peets.com/',
#             'pagemap': {'metatags': [{'msvalidate.01': '03D2C2142D68DB730C2BE12B7C45a8F39',
#                                       'viewport': 'initial-scale=1.0, '
#                                                   'width=device-width'}]},
#             'snippet': "Since 1966, Peet's Coffee has offered superior coffees "
#                        'and teas by sourcing the \n'
#                        'best quality coffee beans and tea leaves in the world '
#                        'and adhering to strict\xa0...',
#             'title': "Peet's Coffee: The Original Craft Coffee"},
#            {'cacheId': 'x4v1eDl2rwsJ',
#             'displayLink': 'www.stumptowncoffee.com',
#             'formattedUrl': 'https://www.stumptowncoffee.com/',
#             'htmlFormattedUrl': 'https://www.stumptown<b>coffee</b>.com/',
#             'htmlSnippet': 'Stumptown <b>Coffee</b> Roasters highest quality '
#                            'fresh roasted <b>coffee</b>; learn to brew, <br>\n'
#                            'subscribe, or visit us in Portland, Seattle, New '
#                            'York, Chicago and Los Angeles.',
#             'htmlTitle': 'Stumptown <b>Coffee</b> Roasters: <b>Coffee</b> '
#                          'Roasted Daily',
#             'kind': 'customsearch#result',
#             'link': 'https://www.stumptowncoffee.com/',
#             'pagemap': {'cse_image': [{'src': 'https://d3r55vhm3z8vu.cloudfront.net/assets/graphics/og-image-870840479ac3621c13bb717eec3adeee.png'}],
#                         'cse_thumbnail': [{'height': '165',
#                                            'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQlKPYouJQP7DrQKXsiblWV9wqQkU9GG0I6ZaFoEAsysTA9hK-cpN2J1YU',
#                                            'width': '305'}],
#                         'metatags': [{'apple-mobile-web-app-capable': 'yes',
#                                       'apple-mobile-web-app-status-bar-style': 'black-translucent',
#                                       'csrf-param': 'authenticity_token',
#                                       'csrf-token': 'MxdoQFYI6NRTElaCeuqWjj+LgwUEjgnQpZ/7jPzs99o=',
#                                       'msapplication-tap-highlight': 'no',
#                                       'og:description': 'Stumptown Coffee '
#                                                         'Roasters highest '
#                                                         'quality fresh roasted '
#                                                         'coffee; learn to '
#                                                         'brew, subscribe, or '
#                                                         'visit us in Portland, '
#                                                         'Seattle, New York, '
#                                                         'Chicago and Los '
#                                                         'Angeles.',
#                                       'og:image': 'https://d3r55vhm3z8vu.cloudfront.net/assets/graphics/og-image-870840479ac3621c13bb717eec3adeee.png',
#                                       'og:site_name': 'Stumptown Coffee '
#                                                       'Roasters',
#                                       'og:title': 'Coffee Roasted Daily | '
#                                                   'Stumptown Coffee Roasters',
#                                       'og:url': 'https://www.stumptowncoffee.com/',
#                                       'viewport': 'width=device-width,initial-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=160'}]},
#             'snippet': 'Stumptown Coffee Roasters highest quality fresh '
#                        'roasted coffee; learn to brew, \n'
#                        'subscribe, or visit us in Portland, Seattle, New York, '
#                        'Chicago and Los Angeles.',
#             'title': 'Stumptown Coffee Roasters: Coffee Roasted Daily'}],
#  'kind': 'customsearch#search',
#  'queries': {'nextPage': [{'count': 10,
#                            'cx': '010439152562262418626:eaztx9vovmv',
#                            'inputEncoding': 'utf8',
#                            'outputEncoding': 'utf8',
#                            'safe': 'off',
#                            'searchTerms': 'Coffee',
#                            'startIndex': 11,
#                            'title': 'Google Custom Search - Coffee',
#                            'totalResults': '1840000000'}],
#              'request': [{'count': 10,
#                           'cx': '010439152562262418626:eaztx9vovmv',
#                           'inputEncoding': 'utf8',
#                           'outputEncoding': 'utf8',
#                           'safe': 'off',
#                           'searchTerms': 'Coffee',
#                           'startIndex': 1,
#                           'title': 'Google Custom Search - Coffee',
#                           'totalResults': '1840000000'}]},
#  'searchInformation': {'formattedSearchTime': '0.55',
#                        'formattedTotalResults': '1,840,000,000',
#                        'searchTime': 0.547749,
#                        'totalResults': '1840000000'},
#  'url': {'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json',
#          'type': 'application/json'}}

# %% [markdown]
# ### Twitter data download

# %% [markdown]
# For download of twitter feeds using Python, consider using the library tweepy. https://tweepy.readthedocs.io/en/latest/getting_started.html
#
# First create an application on Twitter. Follow the steps in https://developer.twitter.com/en/apps/ to obtain the keys belowmentioned.

# %%
consumer_key = "Use your own key etc" 
consumer_secret = "consumer secret"
access_token = "access token"
access_token_secret = "access token secret"

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Najib's lawyer said the court should not accept evidence given by prosecution witnesses of what Jho Low had alleged… https://t.co/gHC5Mn5cwi
# Heard on the Street: The demise of 178-year old British tour operator Thomas Cook is a testament to the profound ch… https://t.co/MU1LXhfmWN
# South Korea has culled around 15,000 pigs since the first case was reported on 17 Sept.
#
# https://t.co/yLdSoL929g
# “I’ve also got enough blood pressure medication to last me over two weeks.” A Scotsman trapped in Florida with his… https://t.co/SWIAwX6yWF
# RT @PlattsOil: Refinery Margin Tracker: Asian refining margins for US crude higher on Saudi supply hitch | #crudeoil #OOTT #refiners | http…
# RT @HumanProgress: On average commodities become 3.4% more affordable each year. That means that the time price of commodities halves every…
# RT @V_of_Europe: Sweden: Racist migrant gang films ruthless beating of young Swedish schoolboy - Voice https://t.co/hsA7lRWpMd
# Nuclear energy too slow, too expensive to save climate - report.
# #YahooFinance
# https://t.co/dY8fdCxxWC
# RT @feeonline: Such a law is merely the logical conclusion of your trade policy. https://t.co/4J0B48fv7O
# RT @RubinReport: And the winner of Twitter for today, September 23, 2019, is Dr. Gad Saad... 👏👏👏 https://t.co/GHLS1rgp7Z
# RT @JanneRiitakorpi: The same court that will decide the fate of jailed Catalan independence leaders just sided with the family of Francisc…
# RT @HumanProgress: Historically, travel was reserved to rich gentlemen of pleasure. Today, global increase of disposable incomes &amp; the decl…
# RT @Comte_dUrgell: A fairly balanced article. Gives brief, appropriate context, without assessing likelihood of Spanish state’s narrative (…
# How to make the most of your Medisave account.
# #YahooFinance
#
# https://t.co/d7hSrM4aTg https://t.co/onfDKTdnTx
# A Minnesota auto parts seller has “put everything else on the back burner” to seek relief from import duties whose… https://t.co/pvSxkqqdHE
# American shoppers so far haven’t felt much price impact from China’s soaring meat purchases, but that could soon ch… https://t.co/OsUCfVjqln
# More House Democrats called for an inquiry into reports President Trump repeatedly pressed Ukraine to probe former… https://t.co/GlQcKaY17F
# Facebook to buy brain science start-up CTRL-labs.
# #YahooFinance
# https://t.co/Vz19wpEP2I
# The Chinese technology hub of Hangzhou will assign government officials to work within 100 local companies in a new… https://t.co/d1NFaj5fmA
# Oil industry refuses to back away from fossil fuels https://t.co/9PSu8YbMUD

# %% [markdown]
# This obtains tweets by the hashtag, in this case 'man utd'.

# %%
manutd = tweepy.Cursor(api.search, q='man utd').items(10)
for tweet in manutd:
   print (tweet.created_at, tweet.text, tweet.lang)
